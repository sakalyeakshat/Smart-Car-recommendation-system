# %%
import pandas as pd
df = pd.read_csv('raw/cars_in.csv')
print(df.shape)
df.head()
# Out:
# (49, 22)
#      Brand     Model  Body_Type  Price_Min_Lakh  Price_Max_Lakh  \
# 0   Maruti  Alto K10  Hatchback            3.99            5.96
# 1   Maruti  S-Presso  Hatchback            4.26            6.11
# 2  Renault      Kwid  Hatchback            4.70            6.45
# 3   Maruti     Ignis  Hatchback            5.84            8.30
# 4   Maruti      Eeco        Van            5.32            6.58
#
#    Price_Avg_Lakh  Price_INR  Mileage_Min_kmpl  Mileage_Max_kmpl  \
# 0           4.975   497500.0             24.39             33.85
# 1           5.185   518500.0             24.44             32.73
# 2           5.575   557500.0             21.70             22.00
# 3           7.070   707000.0             20.89             20.89
# 4           5.950   595000.0             19.60             19.60
#
#    Mileage_Avg_kmpl  ...  Engine_Avg_CC  Safety_Rating  \
# 0            29.120  ...          998.0            2.0
# 1            28.585  ...          998.0            0.0
# ...

# %%
print(df.columns)
# Out:
# Index(['Brand', 'Model', 'Body_Type', 'Price_Min_Lakh', 'Price_Max_Lakh',
#        'Price_Avg_Lakh', 'Price_INR', 'Mileage_Min_kmpl', 'Mileage_Max_kmpl',
#        'Mileage_Avg_kmpl', 'Engine_Min_CC', 'Engine_Max_CC', 'Engine_Avg_CC',
#        'Safety_Rating', 'Safety_Rating_Available', 'NCAP_Body',
#        'Fuel_Type_Primary', 'Fuel_Type_Full', 'Transmission_Primary',
#        'Transmission_Full', 'Seating_Min', 'Seating_Max'],
#       dtype='object')
